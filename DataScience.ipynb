# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")

# %%
# STEP 2: Load dataset

df = pd.read_csv("ultimate_student_productivity_dataset_5000.csv")
df.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %%
# STEP 3: View column names

df = df.dropna()
print("Data cleaned successfully")
# Out:
# Data cleaned successfully

# %%
# STEP 4: Dataset information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            5000 non-null   int64
#  1   age                   5000 non-null   int64
#  2   gender                5000 non-null   object
#  3   academic_level        5000 non-null   object
#  4   study_hours           5000 non-null   float64
#  5   self_study_hours      5000 non-null   float64
#  6   online_classes_hours  5000 non-null   float64
#  7   social_media_hours    5000 non-null   float64
#  8   gaming_hours          5000 non-null   float64
#  9   sleep_hours           5000 non-null   float64
#  10  screen_time_hours     5000 non-null   float64
#  11  exercise_minutes      5000 non-null   int64
#  12  caffeine_intake_mg    5000 non-null   int64
#  13  part_time_job         5000 non-null   int64
#  14  upcoming_deadline     5000 non-null   int64
# ...

# %%
# STEP 5: Check missing values

print(df.isnull().sum())

# Remove missing values

df = df.dropna()

print("Step 5 Complete: Data Cleaned")
# Out:
# student_id              0
# age                     0
# gender                  0
# academic_level          0
# study_hours             0
# self_study_hours        0
# online_classes_hours    0
# social_media_hours      0
# gaming_hours            0
# sleep_hours             0
# screen_time_hours       0
# exercise_minutes        0
# caffeine_intake_mg      0
# part_time_job           0
# upcoming_deadline       0
# internet_quality        0
# mental_health_score     0
# focus_index             0
# burnout_level           0
# productivity_score      0
# exam_score              0
# dtype: int64
# Step 5 Complete: Data Cleaned

# %%
# STEP 6: Scatter Plot

plt.figure(figsize=(8,5))

plt.scatter(df['study_hours'], df['productivity_score'])

plt.title("Relational Plot: Study Hours vs Productivity Score")

plt.xlabel("Study Hours")

plt.ylabel("Productivity Score")

plt.show()

# %%
# STEP 7: Histogram

plt.figure(figsize=(8,5))

plt.hist(df['study_hours'], bins=30)

plt.title("Categorical Plot: Histogram of Study Hours")

plt.xlabel("Study Hours")

plt.ylabel("Frequency")

plt.show()

# %%
# STEP 8: Statistical Plot (HEATMAP)

plt.figure(figsize=(10,8))

correlation = df.corr(numeric_only=True)

sns.heatmap(correlation, annot=True)

plt.title("Statistical Plot: Correlation Heatmap")

plt.show()

# %%
# STEP 9: Statistical Moments

print("Mean")
print(df.mean(numeric_only=True))
# Out:
# Mean
# student_id              2500.500000
# age                       20.520400
# study_hours                4.539594
# self_study_hours           2.478734
# online_classes_hours       2.011984
# social_media_hours         2.998086
# gaming_hours               1.564514
# sleep_hours                7.016492
# screen_time_hours          6.979588
# exercise_minutes          74.535600
# caffeine_intake_mg       251.450400
# part_time_job              0.498200
# upcoming_deadline          0.501400
# mental_health_score        5.507400
# focus_index               29.431616
# burnout_level             45.615324
# productivity_score        37.267716
# exam_score                18.803752
# dtype: float64
